# %% [markdown]
# # **Cheat Sheet**

# %% [markdown]
# ### **Dataverse.11**
# ### 1. Hanindhiya Ika Septiana
# ### 2. Indra Aminudin
# ### 3. Moch Sjaiful Abidin
# ### 4. Rifza Anggriani
# ### 5. Zhafar Tri Adib

# %% [markdown]
# #**Import Library**

# %%
import matplotlib.pyplot as plt
import matplotlib
from matplotlib.pyplot import figure
import numpy as np
import pandas as pd

# %% [markdown]
# # **Scatter Plot**

# %%
titanic = pd.read_csv('https://raw.githubusercontent.com/zhafar3adib/belajar_datascience/master/dataset/train.csv')
titanic.head()
# Out:
#    PassengerId  Survived  Pclass  \
# 0            1         0       3
# 1            2         1       1
# 2            3         1       3
# 3            4         1       1
# 4            5         0       3
#
#                                                 Name     Sex   Age  SibSp  \
# 0                            Braund, Mr. Owen Harris    male  22.0      1
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                             Heikkinen, Miss. Laina  female  26.0      0
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                           Allen, Mr. William Henry    male  35.0      0
#
#    Parch            Ticket     Fare Cabin Embarked
# 0      0         A/5 21171   7.2500   NaN        S
# 1      0          PC 17599  71.2833   C85        C
# 2      0  STON/O2. 3101282   7.9250   NaN        S
# 3      0            113803  53.1000  C123        S
# 4      0            373450   8.0500   NaN        S

# %%
titanic2 = pd.pivot_table(titanic, values='Fare',index='Age',aggfunc='sum')
titanic2 = titanic2.reset_index()
titanic2
# Out:
#       Age      Fare
# 0    0.42    8.5167
# 1    0.67   14.5000
# 2    0.75   38.5166
# 3    0.83   47.7500
# 4    0.92  151.5500
# ..    ...       ...
# 83  70.00   81.5000
# 84  70.50    7.7500
# 85  71.00   84.1584
# 86  74.00    7.7750
# 87  80.00   30.0000
#
# [88 rows x 2 columns]

# %%
colors=titanic2['Fare']

# %%
plt.scatter(
    x=titanic2['Age'], #data untuk x axis
    y=titanic2['Fare'], #data untuk y axis
    s = 100, #ukuran marker
    c =colors, #gradasi warna berdasarkan variabel
    cmap = 'RdYlGn', #jenis warna
    marker = '^', #bentuk marker
    edgecolor = 'lightblue', #warna pinggiran marker
    linewidths = 1, #ukuran pinggiran marker
    alpha = 1 #1 = opaque, 0 = transparent
)
plt.colorbar()
plt.show()

# %% [markdown]
# # **Line Chart**

# %% [markdown]
#       > encoding="ISO-8859-1" ,used to avoid errors "'utf-8' codec can't decode".

# %%
#reading csv dataset
data = pd.read_csv('https://raw.githubusercontent.com/nullbytee/DigitalSkola_DataScience_Batch11/main/dataset/Sample_Superstore.csv', encoding="ISO-8859-1")
data.head()
# Out:
#    Row ID        Order ID  Order Date   Ship Date       Ship Mode Customer ID  \
# 0       1  CA-2016-152156   11/8/2016  11/11/2016    Second Class    CG-12520
# 1       2  CA-2016-152156   11/8/2016  11/11/2016    Second Class    CG-12520
# 2       3  CA-2016-138688   6/12/2016   6/16/2016    Second Class    DV-13045
# 3       4  US-2015-108966  10/11/2015  10/18/2015  Standard Class    SO-20335
# 4       5  US-2015-108966  10/11/2015  10/18/2015  Standard Class    SO-20335
#
#      Customer Name    Segment        Country             City  ...  \
# 0      Claire Gute   Consumer  United States        Henderson  ...
# 1      Claire Gute   Consumer  United States        Henderson  ...
# 2  Darrin Van Huff  Corporate  United States      Los Angeles  ...
# 3   Sean O'Donnell   Consumer  United States  Fort Lauderdale  ...
# 4   Sean O'Donnell   Consumer  United States  Fort Lauderdale  ...
#
#   Postal Code  Region       Product ID         Category Sub-Category  \
# ...

# %%
#data subset
data_line = data[['Order Date','Sales','Profit']].sort_values('Order Date')

#converting into DateTime
data_line['Order Date'] = pd.to_datetime(data_line['Order Date'])

#groupby to get the average Sales and Profit on each day
data_line = data_line.groupby('Order Date').mean()

#showing results
data_line.head()
# Out:
#                  Sales      Profit
# Order Date
# 2014-01-03   16.448000    5.551200
# 2014-01-04   96.020000  -21.996700
# 2014-01-05   19.536000    4.884000
# 2014-01-06  489.677778  150.894711
# 2014-01-07   43.579000  -35.981050

# %% [markdown]
#         > Use 'figsize=[x,x]' to customize the size of the figure.
#         > Use 'color='#xxxxx' to add custom color of the line.
#         > Use 'size=xx' to set font size in the title.

# %%
#visualizing the Line Chart figure size
plt.figure(figsize=[12,5])

#avg sales overtime
plt.plot(data_line.index, 'Sales', data=data_line, color='#F05454')

#avg profit overtime
plt.plot(data_line.index, 'Profit', data=data_line, color='#30475E')

#set title and font size
plt.title("Average Sales and Profit over Time Period (2014-2018)", size=12)

#showing results
plt.show()

# %% [markdown]
# # **Bar Plot**

# %%
consolegame = pd.read_csv('https://raw.githubusercontent.com/Indra2101/digitalskola_ds11/master/Video_Games_Sales_as_at_22_Dec_2016.csv')
consolegame.head()
# Out:
#                        Name Platform  Year_of_Release         Genre Publisher  \
# 0                Wii Sports      Wii           2006.0        Sports  Nintendo
# 1         Super Mario Bros.      NES           1985.0      Platform  Nintendo
# 2            Mario Kart Wii      Wii           2008.0        Racing  Nintendo
# 3         Wii Sports Resort      Wii           2009.0        Sports  Nintendo
# 4  Pokemon Red/Pokemon Blue       GB           1996.0  Role-Playing  Nintendo
#
#    NA_Sales  EU_Sales  JP_Sales  Other_Sales  Global_Sales  Critic_Score  \
# 0     41.36     28.96      3.77         8.45         82.53          76.0
# 1     29.08      3.58      6.81         0.77         40.24           NaN
# 2     15.68     12.76      3.79         3.29         35.52          82.0
# 3     15.61     10.93      3.28         2.95         32.77          80.0
# 4     11.27      8.89     10.22         1.00         31.37           NaN
#
#    Critic_Count User_Score  User_Count Developer Rating
# ...

# %%
consolegame2 = pd.pivot_table(consolegame, values='Global_Sales',index='Platform',aggfunc='sum')
consolegame2 = consolegame2.reset_index()
consolegame2.head()
# Out:
#   Platform  Global_Sales
# 0     2600         97.08
# 1      3DO          0.10
# 2      3DS        259.09
# 3       DC         15.97
# 4       DS        807.10

# %%
#Script for Colored Vertical Bar Plot
x = consolegame2['Platform']#Variabel untuk Axis X
y = consolegame2['Global_Sales']#Variabel untuk Axis Y

f, ax = plt.subplots(figsize=(20,5))#mengatur lebar dan tinggi bar (width,height)
plt.bar(x, y, color = "cyan") #mengatur warna bar chart
plt.show()

# %%
#Script for Colored Horizontal Bar Plot
x = consolegame2['Platform']#Variabel untuk Axis X
y = consolegame2['Global_Sales']#Variabel untuk Axis Y

f, ax = plt.subplots(figsize=(5,20))#mengatur lebar dan tinggi bar (width,height)
plt.barh(x, y, color = "pink") #mengatur warna bar chart
plt.show()

# %% [markdown]
# # **Box Plot**

# %%
# Load Data - Credit Card Customers
data_churn = pd.read_csv('https://raw.githubusercontent.com/Hanin-ika0109/data-science_modules/master/DATASET/BankChurners.csv')
data_churn = data_churn[data_churn.columns[:-2]]
data_churn.head()
# Out:
#    CLIENTNUM     Attrition_Flag  Customer_Age Gender  Dependent_count  \
# 0  768805383  Existing Customer            45      M                3
# 1  818770008  Existing Customer            49      F                5
# 2  713982108  Existing Customer            51      M                3
# 3  769911858  Existing Customer            40      F                4
# 4  709106358  Existing Customer            40      M                3
#
#   Education_Level Marital_Status Income_Category Card_Category  \
# 0     High School        Married     $60K - $80K          Blue
# 1        Graduate         Single  Less than $40K          Blue
# 2        Graduate        Married    $80K - $120K          Blue
# 3     High School        Unknown  Less than $40K          Blue
# 4      Uneducated        Married     $60K - $80K          Blue
#
#    Months_on_book  ...  Months_Inactive_12_mon  Contacts_Count_12_mon  \
# 0              39  ...                       1                      3
# ...

# %%
# Box Plot
red_circle = dict(markerfacecolor='red', marker='o')
plt.boxplot(x=data_churn['Months_on_book'], vert=False, flierprops=red_circle);

# %% [markdown]
# # **Pie Chart**

# %%
# read the dataset
df = pd.read_csv('https://raw.githubusercontent.com/Hanin-ika0109/data-science_modules/master/DATASET/BankChurners.csv')
df.head()
# Out:
#    CLIENTNUM     Attrition_Flag  Customer_Age Gender  Dependent_count  \
# 0  768805383  Existing Customer            45      M                3
# 1  818770008  Existing Customer            49      F                5
# 2  713982108  Existing Customer            51      M                3
# 3  769911858  Existing Customer            40      F                4
# 4  709106358  Existing Customer            40      M                3
#
#   Education_Level Marital_Status Income_Category Card_Category  \
# 0     High School        Married     $60K - $80K          Blue
# 1        Graduate         Single  Less than $40K          Blue
# 2        Graduate        Married    $80K - $120K          Blue
# 3     High School        Unknown  Less than $40K          Blue
# 4      Uneducated        Married     $60K - $80K          Blue
#
#    Months_on_book  ...  Credit_Limit  Total_Revolving_Bal  Avg_Open_To_Buy  \
# 0              39  ...       12691.0                  777          11914.0
# ...

# %%
pd.value_counts(df["Attrition_Flag"])
# Out:
# Existing Customer    8500
# Attrited Customer    1627
# Name: Attrition_Flag, dtype: int64

# %%
churn = pd.value_counts(df["Attrition_Flag"]).tolist()
plt.figure(figsize = (10,6))
plt.title("The Ratio of Normal and Churned Customers")
plt.pie(x = churn, labels = ["Existing Customers", "Attrited Customers"], autopct='%.2f%%')
# Out:
# ([<matplotlib.patches.Wedge at 0x7f6356375990>,
# ...
#  [Text(-0.9628371444551311, 0.5319254019667504, 'Existing Customers'),
#   Text(0.9628371693563555, -0.5319253568930898, 'Attrited Customers')],
#  [Text(-0.525183896975526, 0.29014112834550015, '83.93%'),
#   Text(0.5251839105580121, -0.2901411037598671, '16.07%')])

# %%
gender_normal = df.loc[df["Attrition_Flag"] == "Attrited Customer", ["Gender"]].value_counts().tolist()
gender_churned = df.loc[df["Attrition_Flag"] == "Existing Customer", ["Gender"]].value_counts().tolist()
fig, ax = plt.subplots(1, 2, dpi = 60, figsize = (15,8))
ax[0].set_title("Gender in Normal Customers")
ax[0].pie(x = gender_normal, labels = ["Female", "Male"], autopct='%.2f%%')
ax[1].set_title("Gender in Churned Customers")
ax[1].pie(x = gender_churned, labels = ["Female", "Male"], autopct='%.2f%%')
# Out:
# ([<matplotlib.patches.Wedge at 0x7f6352b7a990>,
# ...
#  [Text(-0.07231539300945998, 1.0976203733230754, 'Female'),
#   Text(0.07231549577609601, -1.097620366552415, 'Male')],
#  [Text(-0.03944475982334181, 0.5987020218125866, '52.09%'),
#   Text(0.03944481587787055, -0.598702018119499, '47.91%')])
